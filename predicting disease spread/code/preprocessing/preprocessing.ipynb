# %% [markdown]
# # Introduction to the Project

# %%
import pandas as pd

# Read data
train = pd.read_csv('dengue_features_train.csv')
test = pd.read_csv('dengue_features_test.csv')
labels = pd.read_csv('dengue_labels_train.csv')

# %%
#Shape of data
dfs = {'train': train,
      'test': test,
      'labels': labels}

for name, df in dfs.items():
    print('Shape of 'f"{name} data {df.shape}")
# Out:
# Shape of train data (1456, 24)
# Shape of test data (416, 24)
# Shape of labels data (1456, 4)

# %%
# Convert week_start_date to datetime object
train['week_start_date'] = pd.to_datetime(train['week_start_date'])

# %%
# Putting week_start_date to become index
train.index = train['week_start_date']

# %%
# Splitting cities
train_sj = train[train['city'] == 'sj'].copy()
train_iq = train[train['city'] == 'iq'].copy()

# %%
# Merging train and labels data
train_sj = train_sj.merge(labels, on=['city', 'year', 'weekofyear'])

# %%
# Setting datetime index
train_sj.index = train_sj['week_start_date']

# %% [markdown]
# # *Imputing Nans*

# %%
# Only columns with missing values
nans_columns = train_sj.columns[4:]

# %%
# Imputing with linear interpolation
linear_sj = train_sj[nans_columns].interpolate(method='linear')

# %%
linear_sj
# Out:
#                   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  precipitation_amt_mm  \
# week_start_date
# 1990-04-30       0.122600  0.103725  0.198483  0.177617                 12.42
# 1990-05-07       0.169900  0.142175  0.162357  0.155486                 22.82
# 1990-05-14       0.032250  0.172967  0.157200  0.170843                 34.54
# 1990-05-21       0.128633  0.245067  0.227557  0.235886                 15.36
# 1990-05-28       0.196200  0.262200  0.251200  0.247340                  7.52
# ...                   ...       ...       ...       ...                   ...
# 2008-03-25       0.077850 -0.039900  0.310471  0.296243                 27.19
# 2008-04-01      -0.038000 -0.016833  0.119371  0.066386                  3.82
# 2008-04-08      -0.155200 -0.052750  0.137757  0.141214                 16.96
# 2008-04-15       0.001800 -0.031558  0.203900  0.209843                  0.00
# 2008-04-22      -0.037000 -0.010367  0.077314  0.090586                  0.00
#
#                  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# week_start_date
# 1990-04-30                  297.572857             297.742857
# 1990-05-07                  298.211429             298.442857
# 1990-05-14                  298.781429             298.878571
# 1990-05-21                  298.987143             299.228571
# 1990-05-28                  299.518571             299.664286
# ...                                ...                    ...
# 2008-03-25                  296.958571             296.957143
# 2008-04-01                  298.081429             298.228571
# 2008-04-08                  297.460000             297.564286
# 2008-04-15                  297.630000             297.778571
# 2008-04-22                  298.672857             298.692857
#
#                  reanalysis_dew_point_temp_k  reanalysis_max_air_temp_k  \
# week_start_date
# 1990-04-30                        292.414286                      299.8
# 1990-05-07                        293.951429                      300.9
# 1990-05-14                        295.434286                      300.5
# 1990-05-21                        295.310000                      301.4
# 1990-05-28                        295.821429                      301.9
# ...                                      ...                        ...
# 2008-03-25                        292.095714                      299.7
# 2008-04-01                        293.235714                      299.8
# 2008-04-08                        292.732857                      299.4
# 2008-04-15                        292.274286                      299.7
# 2008-04-22                        294.280000                      300.9
#
#                  reanalysis_min_air_temp_k  ...  \
# week_start_date                             ...
# 1990-04-30                           295.9  ...
# 1990-05-07                           296.4  ...
# 1990-05-14                           297.3  ...
# 1990-05-21                           297.0  ...
# 1990-05-28                           297.5  ...
# ...                                    ...  ...
# 2008-03-25                           294.4  ...
# 2008-04-01                           296.5  ...
# 2008-04-08                           295.8  ...
# 2008-04-15                           295.9  ...
# 2008-04-22                           295.9  ...
#
#                  reanalysis_relative_humidity_percent  \
# week_start_date
# 1990-04-30                                  73.365714
# 1990-05-07                                  77.368571
# 1990-05-14                                  82.052857
# 1990-05-21                                  80.337143
# 1990-05-28                                  80.460000
# ...                                               ...
# 2008-03-25                                  74.247143
# 2008-04-01                                  74.600000
# 2008-04-08                                  75.027143
# 2008-04-15                                  72.285714
# 2008-04-22                                  76.960000
#
#                  reanalysis_sat_precip_amt_mm  \
# week_start_date
# 1990-04-30                              12.42
# 1990-05-07                              22.82
# 1990-05-14                              34.54
# 1990-05-21                              15.36
# 1990-05-28                               7.52
# ...                                       ...
# 2008-03-25                              27.19
# 2008-04-01                               3.82
# 2008-04-08                              16.96
# 2008-04-15                               0.00
# 2008-04-22                               0.00
#
#                  reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# week_start_date
# 1990-04-30                                   14.012857           2.628571
# 1990-05-07                                   15.372857           2.371429
# 1990-05-14                                   16.848571           2.300000
# 1990-05-21                                   16.672857           2.428571
# 1990-05-28                                   17.210000           3.014286
# ...                                                ...                ...
# 2008-03-25                                   13.644286           2.885714
# 2008-04-01                                   14.662857           2.714286
# 2008-04-08                                   14.184286           2.185714
# 2008-04-15                                   13.858571           2.785714
# 2008-04-22                                   15.671429           3.957143
#
#                  station_avg_temp_c  station_diur_temp_rng_c  \
# week_start_date
# 1990-04-30                25.442857                 6.900000
# 1990-05-07                26.714286                 6.371429
# 1990-05-14                26.714286                 6.485714
# 1990-05-21                27.471429                 6.771429
# 1990-05-28                28.942857                 9.371429
# ...                             ...                      ...
# 2008-03-25                25.042857                 5.785714
# 2008-04-01                26.242857                 6.814286
# 2008-04-08                25.000000                 5.714286
# 2008-04-15                25.314286                 6.242857
# 2008-04-22                27.042857                 7.514286
#
#                  station_max_temp_c  station_min_temp_c  station_precip_mm  \
# week_start_date
# 1990-04-30                     29.4                20.0               16.0
# 1990-05-07                     31.7                22.2                8.6
# 1990-05-14                     32.2                22.8               41.4
# 1990-05-21                     33.3                23.3                4.0
# 1990-05-28                     35.0                23.9                5.8
# ...                             ...                 ...                ...
# 2008-03-25                     30.0                21.1                1.8
# 2008-04-01                     30.6                22.2                0.5
# 2008-04-08                     29.4                21.7               30.7
# 2008-04-15                     29.4                21.7               11.2
# 2008-04-22                     31.7                23.3                0.3
#
#                  total_cases
# week_start_date
# 1990-04-30                 4
# 1990-05-07                 5
# 1990-05-14                 4
# 1990-05-21                 3
# 1990-05-28                 6
# ...                      ...
# 2008-03-25                 4
# 2008-04-01                 3
# 2008-04-08                 1
# 2008-04-15                 3
# 2008-04-22                 5
#
# [936 rows x 21 columns]
